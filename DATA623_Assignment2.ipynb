# %%
import pandas as pd
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("DAD_OUT.csv", encoding="cp1252", infer_datetime_format=True)
data.head()
# Out:
#         PHN_ENC ADMITCAT      ADMT_CAT_NM          ADMIT_DTTM  AGE_DISCH  LOS  \
# 0  291022991560        U  Urgent/Emergent  31OCT2015:20:51:00         71    1
# 1  304130151057        U  Urgent/Emergent  25OCT2015:16:45:00         46    6
# 2  177811902619        L         Elective  21OCT2015:09:12:00         31    1
# 3   44201102153        L         Elective  29OCT2015:07:26:00         36    2
# 4  242215672181        U  Urgent/Emergent  15DEC2015:01:52:00         50    7
#
#              DIS_DTTM  DISP               DISP_NM DXCODE1  ... PROCCODE11  \
# 0  31OCT2015:23:00:00     6                   AMA    F191  ...        NaN
# 1  31OCT2015:16:25:00     5  Home without support    K451  ...        NaN
# 2  22OCT2015:19:00:00     5  Home without support  O68201  ...        NaN
# 3  31OCT2015:17:01:00     5  Home without support  O36531  ...        NaN
# 4  22DEC2015:14:00:00     5  Home without support  S72080  ...        NaN
#
# ...

# %%
dx_cols = [col for col in data.columns if "DXCODE" in col]
dx_freq = data[dx_cols].stack().value_counts()
dx_freq.head(13)
# Out:
# I100      5987
# Z37000    4590
# I500      1503
# N390      1502
# I4890     1444
# E1152     1339
# E119      1285
# N179      1253
# O70101    1233
# I2510     1164
# U989      1065
# O68001    1027
# J189      1016
# dtype: int64

# %%
dx_freq10 = dx_freq.head(13)
dx_freq10.sum()
# Out:
# 24408

# %%
dx_freq10.sum() / dx_freq.sum()
# Out:
# 0.18097963904913025

# %%
dx_freq.sum()
# Out:
# 134866

# %%
# I100
data0 = data.loc[(data["DXCODE1"] == "I100") | 
                 (data["DXCODE2"] == "I100") |
                 (data["DXCODE3"] == "I100") |
                 (data["DXCODE4"] == "I100") |
                 (data["DXCODE5"] == "I100") |
                 (data["DXCODE6"] == "I100") |
                 (data["DXCODE7"] == "I100") |
                 (data["DXCODE8"] == "I100") |
                 (data["DXCODE9"] == "I100") |
                 (data["DXCODE10"] == "I100") |
                 (data["DXCODE11"] == "I100") |
                 (data["DXCODE12"] == "I100") |
                 (data["DXCODE13"] == "I100") |
                 (data["DXCODE14"] == "I100") |
                 (data["DXCODE15"] == "I100") |
                 (data["DXCODE16"] == "I100") |
                 (data["DXCODE17"] == "I100") |
                 (data["DXCODE18"] == "I100") |
                 (data["DXCODE19"] == "I100") |
                 (data["DXCODE20"] == "I100") |
                 (data["DXCODE21"] == "I100") |
                 (data["DXCODE22"] == "I100") |
                 (data["DXCODE23"] == "I100") |
                 (data["DXCODE24"] == "I100") |
                 (data["DXCODE25"] == "I100"),
                 "LOS"]
data0.describe()
# Out:
# count    5984.000000
# mean       13.767547
# std        32.872735
# min         1.000000
# 25%         3.000000
# 50%         5.000000
# 75%        12.000000
# max      1016.000000
# Name: LOS, dtype: float64

# %%
# Z37000
data1 = data.loc[(data["DXCODE1"] == "Z37000") | 
                 (data["DXCODE2"] == "Z37000") |
                 (data["DXCODE3"] == "Z37000") |
                 (data["DXCODE4"] == "Z37000") |
                 (data["DXCODE5"] == "Z37000") |
                 (data["DXCODE6"] == "Z37000") |
                 (data["DXCODE7"] == "Z37000") |
                 (data["DXCODE8"] == "Z37000") |
                 (data["DXCODE9"] == "Z37000") |
                 (data["DXCODE10"] == "Z37000") |
                 (data["DXCODE11"] == "Z37000") |
                 (data["DXCODE12"] == "Z37000") |
                 (data["DXCODE13"] == "Z37000") |
                 (data["DXCODE14"] == "Z37000") |
                 (data["DXCODE15"] == "Z37000") |
                 (data["DXCODE16"] == "Z37000") |
                 (data["DXCODE17"] == "Z37000") |
                 (data["DXCODE18"] == "Z37000") |
                 (data["DXCODE19"] == "Z37000") |
                 (data["DXCODE20"] == "Z37000") |
                 (data["DXCODE21"] == "Z37000") |
                 (data["DXCODE22"] == "Z37000") |
                 (data["DXCODE23"] == "Z37000") |
                 (data["DXCODE24"] == "Z37000") |
                 (data["DXCODE25"] == "Z37000"),
                 "LOS"]
data1.describe()
# Out:
# count    4588.000000
# mean        1.965780
# std         1.525142
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max        36.000000
# Name: LOS, dtype: float64

# %%
# I500
data2 = data.loc[(data["DXCODE1"] == "I500") | 
                 (data["DXCODE2"] == "I500") |
                 (data["DXCODE3"] == "I500") |
                 (data["DXCODE4"] == "I500") |
                 (data["DXCODE5"] == "I500") |
                 (data["DXCODE6"] == "I500") |
                 (data["DXCODE7"] == "I500") |
                 (data["DXCODE8"] == "I500") |
                 (data["DXCODE9"] == "I500") |
                 (data["DXCODE10"] == "I500") |
                 (data["DXCODE11"] == "I500") |
                 (data["DXCODE12"] == "I500") |
                 (data["DXCODE13"] == "I500") |
                 (data["DXCODE14"] == "I500") |
                 (data["DXCODE15"] == "I500") |
                 (data["DXCODE16"] == "I500") |
                 (data["DXCODE17"] == "I500") |
                 (data["DXCODE18"] == "I500") |
                 (data["DXCODE19"] == "I500") |
                 (data["DXCODE20"] == "I500") |
                 (data["DXCODE21"] == "I500") |
                 (data["DXCODE22"] == "I500") |
                 (data["DXCODE23"] == "I500") |
                 (data["DXCODE24"] == "I500") |
                 (data["DXCODE25"] == "I500"),
                 "LOS"]
data2.describe()
# Out:
# count    1499.000000
# mean       17.847899
# std        46.863032
# min         1.000000
# 25%         4.000000
# 50%         9.000000
# 75%        17.000000
# max      1303.000000
# Name: LOS, dtype: float64

# %%
# N390
data3 = data.loc[(data["DXCODE1"] == "N390") | 
                 (data["DXCODE2"] == "N390") |
                 (data["DXCODE3"] == "N390") |
                 (data["DXCODE4"] == "N390") |
                 (data["DXCODE5"] == "N390") |
                 (data["DXCODE6"] == "N390") |
                 (data["DXCODE7"] == "N390") |
                 (data["DXCODE8"] == "N390") |
                 (data["DXCODE9"] == "N390") |
                 (data["DXCODE10"] == "N390") |
                 (data["DXCODE11"] == "N390") |
                 (data["DXCODE12"] == "N390") |
                 (data["DXCODE13"] == "N390") |
                 (data["DXCODE14"] == "N390") |
                 (data["DXCODE15"] == "N390") |
                 (data["DXCODE16"] == "N390") |
                 (data["DXCODE17"] == "N390") |
                 (data["DXCODE18"] == "N390") |
                 (data["DXCODE19"] == "N390") |
                 (data["DXCODE20"] == "N390") |
                 (data["DXCODE21"] == "N390") |
                 (data["DXCODE22"] == "N390") |
                 (data["DXCODE23"] == "N390") |
                 (data["DXCODE24"] == "N390") |
                 (data["DXCODE25"] == "N390"),
                 "LOS"]
data3.describe()
# Out:
# count    1491.000000
# mean       26.918176
# std        52.453636
# min         1.000000
# 25%         5.000000
# 50%        10.000000
# 75%        30.000000
# max       748.000000
# Name: LOS, dtype: float64

# %%
# I4890
data4 = data.loc[(data["DXCODE1"] == "I4890") | 
                 (data["DXCODE2"] == "I4890") |
                 (data["DXCODE3"] == "I4890") |
                 (data["DXCODE4"] == "I4890") |
                 (data["DXCODE5"] == "I4890") |
                 (data["DXCODE6"] == "I4890") |
                 (data["DXCODE7"] == "I4890") |
                 (data["DXCODE8"] == "I4890") |
                 (data["DXCODE9"] == "I4890") |
                 (data["DXCODE10"] == "I4890") |
                 (data["DXCODE11"] == "I4890") |
                 (data["DXCODE12"] == "I4890") |
                 (data["DXCODE13"] == "I4890") |
                 (data["DXCODE14"] == "I4890") |
                 (data["DXCODE15"] == "I4890") |
                 (data["DXCODE16"] == "I4890") |
                 (data["DXCODE17"] == "I4890") |
                 (data["DXCODE18"] == "I4890") |
                 (data["DXCODE19"] == "I4890") |
                 (data["DXCODE20"] == "I4890") |
                 (data["DXCODE21"] == "I4890") |
                 (data["DXCODE22"] == "I4890") |
                 (data["DXCODE23"] == "I4890") |
                 (data["DXCODE24"] == "I4890") |
                 (data["DXCODE25"] == "I4890"),
                 "LOS"]
data4.describe()
# Out:
# count    1443.000000
# mean       16.655579
# std        27.271886
# min         1.000000
# 25%         3.500000
# 50%         8.000000
# 75%        17.000000
# max       387.000000
# Name: LOS, dtype: float64

# %%
# E1152
data5 = data.loc[(data["DXCODE1"] == "E1152") | 
                 (data["DXCODE2"] == "E1152") |
                 (data["DXCODE3"] == "E1152") |
                 (data["DXCODE4"] == "E1152") |
                 (data["DXCODE5"] == "E1152") |
                 (data["DXCODE6"] == "E1152") |
                 (data["DXCODE7"] == "E1152") |
                 (data["DXCODE8"] == "E1152") |
                 (data["DXCODE9"] == "E1152") |
                 (data["DXCODE10"] == "E1152") |
                 (data["DXCODE11"] == "E1152") |
                 (data["DXCODE12"] == "E1152") |
                 (data["DXCODE13"] == "E1152") |
                 (data["DXCODE14"] == "E1152") |
                 (data["DXCODE15"] == "E1152") |
                 (data["DXCODE16"] == "E1152") |
                 (data["DXCODE17"] == "E1152") |
                 (data["DXCODE18"] == "E1152") |
                 (data["DXCODE19"] == "E1152") |
                 (data["DXCODE20"] == "E1152") |
                 (data["DXCODE21"] == "E1152") |
                 (data["DXCODE22"] == "E1152") |
                 (data["DXCODE23"] == "E1152") |
                 (data["DXCODE24"] == "E1152") |
                 (data["DXCODE25"] == "E1152"),
                 "LOS"]
data5.describe()
# Out:
# count    1335.000000
# mean       14.107116
# std        29.308672
# min         1.000000
# 25%         3.000000
# 50%         6.000000
# 75%        13.000000
# max       606.000000
# Name: LOS, dtype: float64

# %%
# E119
data6 = data.loc[(data["DXCODE1"] == "E119") | 
                 (data["DXCODE2"] == "E119") |
                 (data["DXCODE3"] == "E119") |
                 (data["DXCODE4"] == "E119") |
                 (data["DXCODE5"] == "E119") |
                 (data["DXCODE6"] == "E119") |
                 (data["DXCODE7"] == "E119") |
                 (data["DXCODE8"] == "E119") |
                 (data["DXCODE9"] == "E119") |
                 (data["DXCODE10"] == "E119") |
                 (data["DXCODE11"] == "E119") |
                 (data["DXCODE12"] == "E119") |
                 (data["DXCODE13"] == "E119") |
                 (data["DXCODE14"] == "E119") |
                 (data["DXCODE15"] == "E119") |
                 (data["DXCODE16"] == "E119") |
                 (data["DXCODE17"] == "E119") |
                 (data["DXCODE18"] == "E119") |
                 (data["DXCODE19"] == "E119") |
                 (data["DXCODE20"] == "E119") |
                 (data["DXCODE21"] == "E119") |
                 (data["DXCODE22"] == "E119") |
                 (data["DXCODE23"] == "E119") |
                 (data["DXCODE24"] == "E119") |
                 (data["DXCODE25"] == "E119"),
                 "LOS"]
data6.describe()
# Out:
# count    1285.000000
# mean       12.568872
# std        44.101564
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         9.000000
# max      1016.000000
# Name: LOS, dtype: float64

# %%
# N179
data7 = data.loc[(data["DXCODE1"] == "N179") | 
                 (data["DXCODE2"] == "N179") |
                 (data["DXCODE3"] == "N179") |
                 (data["DXCODE4"] == "N179") |
                 (data["DXCODE5"] == "N179") |
                 (data["DXCODE6"] == "N179") |
                 (data["DXCODE7"] == "N179") |
                 (data["DXCODE8"] == "N179") |
                 (data["DXCODE9"] == "N179") |
                 (data["DXCODE10"] == "N179") |
                 (data["DXCODE11"] == "N179") |
                 (data["DXCODE12"] == "N179") |
                 (data["DXCODE13"] == "N179") |
                 (data["DXCODE14"] == "N179") |
                 (data["DXCODE15"] == "N179") |
                 (data["DXCODE16"] == "N179") |
                 (data["DXCODE17"] == "N179") |
                 (data["DXCODE18"] == "N179") |
                 (data["DXCODE19"] == "N179") |
                 (data["DXCODE20"] == "N179") |
                 (data["DXCODE21"] == "N179") |
                 (data["DXCODE22"] == "N179") |
                 (data["DXCODE23"] == "N179") |
                 (data["DXCODE24"] == "N179") |
                 (data["DXCODE25"] == "N179"),
                 "LOS"]
data7.describe()
# Out:
# count    1252.000000
# mean       17.619010
# std        32.876307
# min         1.000000
# 25%         4.000000
# 50%         8.000000
# 75%        18.000000
# max       679.000000
# Name: LOS, dtype: float64

# %%
# O70101
data8 = data.loc[(data["DXCODE1"] == "O70101") | 
                 (data["DXCODE2"] == "O70101") |
                 (data["DXCODE3"] == "O70101") |
                 (data["DXCODE4"] == "O70101") |
                 (data["DXCODE5"] == "O70101") |
                 (data["DXCODE6"] == "O70101") |
                 (data["DXCODE7"] == "O70101") |
                 (data["DXCODE8"] == "O70101") |
                 (data["DXCODE9"] == "O70101") |
                 (data["DXCODE10"] == "O70101") |
                 (data["DXCODE11"] == "O70101") |
                 (data["DXCODE12"] == "O70101") |
                 (data["DXCODE13"] == "O70101") |
                 (data["DXCODE14"] == "O70101") |
                 (data["DXCODE15"] == "O70101") |
                 (data["DXCODE16"] == "O70101") |
                 (data["DXCODE17"] == "O70101") |
                 (data["DXCODE18"] == "O70101") |
                 (data["DXCODE19"] == "O70101") |
                 (data["DXCODE20"] == "O70101") |
                 (data["DXCODE21"] == "O70101") |
                 (data["DXCODE22"] == "O70101") |
                 (data["DXCODE23"] == "O70101") |
                 (data["DXCODE24"] == "O70101") |
                 (data["DXCODE25"] == "O70101"),
                 "LOS"]
data8.describe()
# Out:
# count    1233.000000
# mean        1.666667
# std         0.908116
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max        16.000000
# Name: LOS, dtype: float64

# %%
# I2510
data9 = data.loc[(data["DXCODE1"] == "I2510") | 
                 (data["DXCODE2"] == "I2510") |
                 (data["DXCODE3"] == "I2510") |
                 (data["DXCODE4"] == "I2510") |
                 (data["DXCODE5"] == "I2510") |
                 (data["DXCODE6"] == "I2510") |
                 (data["DXCODE7"] == "I2510") |
                 (data["DXCODE8"] == "I2510") |
                 (data["DXCODE9"] == "I2510") |
                 (data["DXCODE10"] == "I2510") |
                 (data["DXCODE11"] == "I2510") |
                 (data["DXCODE12"] == "I2510") |
                 (data["DXCODE13"] == "I2510") |
                 (data["DXCODE14"] == "I2510") |
                 (data["DXCODE15"] == "I2510") |
                 (data["DXCODE16"] == "I2510") |
                 (data["DXCODE17"] == "I2510") |
                 (data["DXCODE18"] == "I2510") |
                 (data["DXCODE19"] == "I2510") |
                 (data["DXCODE20"] == "I2510") |
                 (data["DXCODE21"] == "I2510") |
                 (data["DXCODE22"] == "I2510") |
                 (data["DXCODE23"] == "I2510") |
                 (data["DXCODE24"] == "I2510") |
                 (data["DXCODE25"] == "I2510"),
                 "LOS"]
data9.describe()
# Out:
# count    1162.000000
# mean        9.393287
# std        22.252046
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         9.000000
# max       387.000000
# Name: LOS, dtype: float64

# %%
# U989
data10 = data.loc[(data["DXCODE1"] == "U989") | 
                 (data["DXCODE2"] == "U989") |
                 (data["DXCODE3"] == "U989") |
                 (data["DXCODE4"] == "U989") |
                 (data["DXCODE5"] == "U989") |
                 (data["DXCODE6"] == "U989") |
                 (data["DXCODE7"] == "U989") |
                 (data["DXCODE8"] == "U989") |
                 (data["DXCODE9"] == "U989") |
                 (data["DXCODE10"] == "U989") |
                 (data["DXCODE11"] == "U989") |
                 (data["DXCODE12"] == "U989") |
                 (data["DXCODE13"] == "U989") |
                 (data["DXCODE14"] == "U989") |
                 (data["DXCODE15"] == "U989") |
                 (data["DXCODE16"] == "U989") |
                 (data["DXCODE17"] == "U989") |
                 (data["DXCODE18"] == "U989") |
                 (data["DXCODE19"] == "U989") |
                 (data["DXCODE20"] == "U989") |
                 (data["DXCODE21"] == "U989") |
                 (data["DXCODE22"] == "U989") |
                 (data["DXCODE23"] == "U989") |
                 (data["DXCODE24"] == "U989") |
                 (data["DXCODE25"] == "U989"),
                 "LOS"]
data10.describe()
# Out:
# count    1058.000000
# mean       11.647448
# std        24.730324
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%        10.000000
# max       487.000000
# Name: LOS, dtype: float64

# %%
# O68001
data11 = data.loc[(data["DXCODE1"] == "O68001") | 
                 (data["DXCODE2"] == "O68001") |
                 (data["DXCODE3"] == "O68001") |
                 (data["DXCODE4"] == "O68001") |
                 (data["DXCODE5"] == "O68001") |
                 (data["DXCODE6"] == "O68001") |
                 (data["DXCODE7"] == "O68001") |
                 (data["DXCODE8"] == "O68001") |
                 (data["DXCODE9"] == "O68001") |
                 (data["DXCODE10"] == "O68001") |
                 (data["DXCODE11"] == "O68001") |
                 (data["DXCODE12"] == "O68001") |
                 (data["DXCODE13"] == "O68001") |
                 (data["DXCODE14"] == "O68001") |
                 (data["DXCODE15"] == "O68001") |
                 (data["DXCODE16"] == "O68001") |
                 (data["DXCODE17"] == "O68001") |
                 (data["DXCODE18"] == "O68001") |
                 (data["DXCODE19"] == "O68001") |
                 (data["DXCODE20"] == "O68001") |
                 (data["DXCODE21"] == "O68001") |
                 (data["DXCODE22"] == "O68001") |
                 (data["DXCODE23"] == "O68001") |
                 (data["DXCODE24"] == "O68001") |
                 (data["DXCODE25"] == "O68001"),
                 "LOS"]
data11.describe()
# Out:
# count    1027.000000
# mean        2.236611
# std         1.878239
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        46.000000
# Name: LOS, dtype: float64

# %%
# J189
data12 = data.loc[(data["DXCODE1"] == "J189") | 
                 (data["DXCODE2"] == "J189") |
                 (data["DXCODE3"] == "J189") |
                 (data["DXCODE4"] == "J189") |
                 (data["DXCODE5"] == "J189") |
                 (data["DXCODE6"] == "J189") |
                 (data["DXCODE7"] == "J189") |
                 (data["DXCODE8"] == "J189") |
                 (data["DXCODE9"] == "J189") |
                 (data["DXCODE10"] == "J189") |
                 (data["DXCODE11"] == "J189") |
                 (data["DXCODE12"] == "J189") |
                 (data["DXCODE13"] == "J189") |
                 (data["DXCODE14"] == "J189") |
                 (data["DXCODE15"] == "J189") |
                 (data["DXCODE16"] == "J189") |
                 (data["DXCODE17"] == "J189") |
                 (data["DXCODE18"] == "J189") |
                 (data["DXCODE19"] == "J189") |
                 (data["DXCODE20"] == "J189") |
                 (data["DXCODE21"] == "J189") |
                 (data["DXCODE22"] == "J189") |
                 (data["DXCODE23"] == "J189") |
                 (data["DXCODE24"] == "J189") |
                 (data["DXCODE25"] == "J189"),
                 "LOS"]
data12_d = data12.describe()
display(data12_d)
# Out:
# count    1010.000000
# mean       15.625743
# std        26.252236
# min         1.000000
# 25%         4.000000
# 50%         7.000000
# 75%        15.000000
# max       239.000000
# Name: LOS, dtype: float64

# %%
#plt.boxplot([data0, data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11, data12])
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)
ax.boxplot([np.log(data0), 
             np.log(data1), 
             np.log(data2), 
             np.log(data3), 
             np.log(data4), 
             np.log(data5), 
             np.log(data6),
             np.log(data7),
             np.log(data8),
             np.log(data9),
             np.log(data10),
             np.log(data11),
             np.log(data12)],
            labels=["I100", "Z37000", "I500", "N390", "I4890", "E1152", "E119", "N179", "O70101", "I2510", "U989", "O68001", "J189"],
           vert=False)
ax.set_title("Length of stay of AHS patients coded with common ICD-10 codes")
ax.set_xlabel("Log length of stay (days)")
plt.show()

# %%
data

# %%
d_data
# Out:
#      2      3      4      7      9      12     17     20     21     22     \
# LOS    NaN    NaN    7.0    NaN   10.0   81.0    NaN    1.0    NaN    NaN
# LOS    1.0    2.0    NaN    1.0    NaN    NaN    1.0    NaN    1.0    2.0
#
#      ...  28603  28604  28606  28610  28611  28617  28619  28621  28627  28633
# LOS  ...    3.0   12.0    5.0    2.0    NaN    2.0    3.0    NaN    4.0    NaN
# LOS  ...    NaN    NaN    NaN    NaN    1.0    NaN    NaN    1.0    NaN    2.0
#
# [2 rows x 10572 columns]

# %%
d_data = pd.DataFrame([data0.describe(),
                       data1.describe(),
                       data2.describe(),
                       data3.describe(),
                      data4.describe(),
                      data5.describe(),
                      data6.describe(),
                      data7.describe(),
                      data8.describe(),
                      data9.describe(),
                      data10.describe(),
                      data11.describe(),
                      data12.describe()],
                     index=["I100", "Z37000", "1500", "N390", "I4890", "E1152", "E119", "N179", "O70101", "I2510", "U989", "O68001", "J189"])

# %%
d_data
# Out:
#          count       mean        std  min  25%   50%   75%     max
# I100    5984.0  13.767547  32.872735  1.0  3.0   5.0  12.0  1016.0
# Z37000  4588.0   1.965780   1.525142  1.0  1.0   2.0   2.0    36.0
# 1500    1499.0  17.847899  46.863032  1.0  4.0   9.0  17.0  1303.0
# N390    1491.0  26.918176  52.453636  1.0  5.0  10.0  30.0   748.0
# I4890   1443.0  16.655579  27.271886  1.0  3.5   8.0  17.0   387.0
# E1152   1335.0  14.107116  29.308672  1.0  3.0   6.0  13.0   606.0
# E119    1285.0  12.568872  44.101564  1.0  2.0   4.0   9.0  1016.0
# N179    1252.0  17.619010  32.876307  1.0  4.0   8.0  18.0   679.0
# O70101  1233.0   1.666667   0.908116  1.0  1.0   1.0   2.0    16.0
# I2510   1162.0   9.393287  22.252046  1.0  2.0   4.0   9.0   387.0
# U989    1058.0  11.647448  24.730324  1.0  2.0   4.0  10.0   487.0
# O68001  1027.0   2.236611   1.878239  1.0  1.0   2.0   3.0    46.0
# J189    1010.0  15.625743  26.252236  1.0  4.0   7.0  15.0   239.0

# %%
median = [data0.median(),
                       data1.median(),
                       data2.median(),
                       data3.median(),
                      data4.median(),
                      data5.median(),
                      data6.median(),
                      data7.median(),
                      data8.median(),
                      data9.median(),
                      data10.median(),
                      data11.median(),
                      data12.median()]

# %%
d_data.insert(1, "median", median)

# %%
d_data
# Out:
#          count  median       mean        std  min  25%   50%   75%     max
# I100    5984.0     5.0  13.767547  32.872735  1.0  3.0   5.0  12.0  1016.0
# Z37000  4588.0     2.0   1.965780   1.525142  1.0  1.0   2.0   2.0    36.0
# 1500    1499.0     9.0  17.847899  46.863032  1.0  4.0   9.0  17.0  1303.0
# N390    1491.0    10.0  26.918176  52.453636  1.0  5.0  10.0  30.0   748.0
# I4890   1443.0     8.0  16.655579  27.271886  1.0  3.5   8.0  17.0   387.0
# E1152   1335.0     6.0  14.107116  29.308672  1.0  3.0   6.0  13.0   606.0
# E119    1285.0     4.0  12.568872  44.101564  1.0  2.0   4.0   9.0  1016.0
# N179    1252.0     8.0  17.619010  32.876307  1.0  4.0   8.0  18.0   679.0
# O70101  1233.0     1.0   1.666667   0.908116  1.0  1.0   1.0   2.0    16.0
# I2510   1162.0     4.0   9.393287  22.252046  1.0  2.0   4.0   9.0   387.0
# U989    1058.0     4.0  11.647448  24.730324  1.0  2.0   4.0  10.0   487.0
# ...

# %%
d_data.to_csv("ddata.csv")

# %%
plt.hist(np.log(data3), bins=10)
plt.show()
